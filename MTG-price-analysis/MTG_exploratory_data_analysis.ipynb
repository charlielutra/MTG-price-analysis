# %%
# Setup - copy-pasted from 2A

# Python ≥3.9 is required
import sys
assert sys.version_info >= (3, 9)

# Scikit-Learn ≥1.0 is required
import sklearn
assert sklearn.__version__ >= "1.0"

# Common imports
import numpy as np
import pandas as pd

# To plot pretty figures
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
mpl.rc('axes', labelsize=14)
#mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Precision options
np.set_printoptions(precision=2)
pd.options.display.float_format = '{:.3f}'.format

# Statistical analysis and testing
from statsmodels.formula.api import ols
import statsmodels.api as sm

# Ignore useless warnings (see SciPy issue #5998 and seaborn/matplotlib bug)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")
warnings.filterwarnings(action="ignore", message="The figure layout has changed to tight")

import json

# %%
f=open("default-cards-20240806090619.json")
raw_data = json.load(f)
# raw_data[0]

# %%
df = pd.DataFrame.from_dict(raw_data)

# %%
def expand_dict_features(data: pd.DataFrame) -> pd.DataFrame:
    engineered_data = data.copy()
    legalities_df = pd.DataFrame(engineered_data["legalities"].tolist())
    prices_df = pd.DataFrame(engineered_data["prices"].tolist())
    engineered_data = engineered_data.drop(columns=["legalities","prices"])
    engineered_data = engineered_data.join(legalities_df)
    engineered_data = engineered_data.join(prices_df)
    return engineered_data

# %%
def drop_junk_features(data: pd.DataFrame) -> pd.DataFrame:
    junk_columns = [
    # These provide no info - the entire dataset has "card", "en", null, False, and False respectively
    "object",
    "lang",
    "attraction_lights",
    "oversized",
    "variation",

    # Others that need to gtfo:
    "games",


    # Various IDs
    "oracle_id", 
    "arena_id", 
    "multiverse_ids", 
    "tcgplayer_id", 
    "cardmarket_id",
    "artist_ids",
    "illustration_id", 
    "tcgplayer_etched_id",
    "mtgo_foil_id",
    "collector_number",
    "set_id",


    # Various URIs 
    "uri", 
    "scryfall_uri", 
    "image_status",
    "image_uris",
    "set_name",
    "set_uri",
    "set_search_uri",
    "scryfall_set_uri",
    "rulings_uri",
    "prints_search_uri",
    "related_uris",
    "purchase_uris",
    "card_back_id",


    # Random text-based stuff the algo won't understand
    "oracle_text",
    "flavor_text",
    "artist",
    "preview",

    "all_parts",
    "promo_types",
    "finishes",

    # Misc other stuff irrelevant to data analysis
    "highres_image", 


    # Stuff with <1000 non-null
    "card_faces",
    "loyalty",          # Tempted to keep this one, but I'll be consistent for now
    "printed_name",
    "flavor_name",
    "color_indicator",
    "printed_type_line",
    "printed_text",
    "variation_of",
    "life_modifier",
    "hand_modifier",
    "content_warning",

    "security_stamp",
    "watermark",
    "frame_effects",

    # These ones are <1000, but they are also just bools, so I'll let these ones go

    #"textless",
    #"full_art",       # Also kinda wanna break the rules on this one

    #"reserved",     # VERY tempted here
    #"story_spotlight",


    "set", # Useless to the algorithm - it can get what it needs from card age + set_type

    # Prices other than tix (I don't want the program to have these)
    "usd",
    "usd_foil",
    "usd_etched",
    "eur",
    "eur_foil",
    

    # Arena-specific format legalities (irrelevant to MTGO)
    "brawl",
    "historic",
    "standardbrawl",
    "alchemy",
    "explorer", 
    "gladiator",
    "timeless",

    # Other format legalities that no one gives a shit about
    #"future",
    #"paupercommander",
    #"duel",
    #"oldschool",
    #"premodern",
    #"predh",

    # 
]
    engineered_data = data.copy()
    engineered_data = engineered_data.drop(columns=junk_columns)
    return engineered_data

# %%
def clean_dataset(data: pd.DataFrame) -> pd.DataFrame:
    # I want to only keep cards that are relevant to actual play of the game, on MTGO
    # Therefore a) remove any card not on MTGO (eg. alchemy-only cards, Fallout cards etc)
    # ... and also need to remove cards which are on mtgo but inexplicably don't have a tix value stored! 

    # b) remove anything "banned" in Vintage (ie. ante, conspiracy, dexterity, subgame cards)
    # ...actually those cards aren't on MTGO anyway! -> unnecessary
    
    engineered_data = data.copy()
    #engineered_data = engineered_data.dropna()
    engineered_data = engineered_data[engineered_data.tix.notna()]
    engineered_data = engineered_data[engineered_data.vintage != "not_legal"]
    engineered_data = engineered_data[engineered_data.vintage != "banned"]
    #engineered_data = engineered_data[engineered_data.colors.notna()] # Temporary fix, removes all DFCs, replace and impute them at some point
    return engineered_data

# %% [markdown]
# # END OF COPY-PASTE

# %%
df2 = expand_dict_features(df)
df3 = drop_junk_features(df2)
df4 = clean_dataset(df3)
df4
# Out:
#                                          id    mtgo_id  \
# 0      0000419b-0bba-4488-8f7a-6194544ce91e 129825.000
# 1      0000579f-7b35-4ed3-b44c-db2a538066fe  25527.000
# 2      00006596-1166-4a79-8443-ca9f82e6db4e  34586.000
# 4      0000cd57-91fe-411f-b798-646e965eec37  65170.000
# 7      0001e77a-7fff-49d2-a55c-42f6fdf6db08 116428.000
# ...                                     ...        ...
# 97263  fffaa737-ce46-4f35-aa8c-bd9bb77ed9f6  57710.000
# 97266  fffc85fb-1a40-4f83-a36e-cec0b7be658a 127441.000
# 97268  fffce2f7-b619-4483-a75e-916343194641  19591.000
# 97269  fffdf7f3-a230-417a-883a-069aabcbcca7 117284.000
# 97270  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86  66467.000
#
#                                         name released_at     layout  \
# 0                                     Forest  2024-08-02     normal
# 1                                Fury Sliver  2006-10-06     normal
# 2                              Kor Outfitter  2009-10-02     normal
# 4                              Siren Lookout  2017-09-29     normal
# 7      Obyra's Attendants // Desperate Parry  2023-09-08  adventure
# ...                                      ...         ...        ...
# 97263                           Angel's Tomb  2015-07-17     normal
# 97266                    Aggressive Biomancy  2024-06-14     normal
# 97268                           Horned Troll  2003-07-28     normal
# 97269                    Faerie Bladecrafter  2023-09-08     normal
# 97270                    Exultant Skymarcher  2018-01-19     normal
#
#               mana_cost   cmc  \
# 0                       0.000
# 1                {5}{R} 6.000
# 2                {W}{W} 2.000
# 4                {2}{U} 3.000
# 7      {4}{U} // {1}{U} 5.000
# ...                 ...   ...
# 97263               {3} 3.000
# 97266      {X}{X}{G}{U} 2.000
# 97268            {2}{G} 3.000
# 97269            {2}{B} 3.000
# 97270         {1}{W}{W} 3.000
#
#                                              type_line  colors color_identity  \
# 0                                  Basic Land — Forest      []            [G]
# 1                                    Creature — Sliver     [R]            [R]
# 2                               Creature — Kor Soldier     [W]            [W]
# 4                              Creature — Siren Pirate     [U]            [U]
# 7      Creature — Faerie Wizard // Instant — Adventure     [U]            [U]
# ...                                                ...     ...            ...
# 97263                                         Artifact      []             []
# 97266                                          Sorcery  [G, U]         [G, U]
# 97268                                 Creature — Troll     [G]            [G]
# 97269                          Creature — Faerie Rogue     [B]            [B]
# 97270                       Creature — Vampire Soldier     [W]            [W]
#
#        ... vintage      penny  commander  oathbreaker  paupercommander   duel  \
# 0      ...   legal      legal      legal        legal            legal  legal
# 1      ...   legal  not_legal      legal        legal       restricted  legal
# 2      ...   legal      legal      legal        legal            legal  legal
# 4      ...   legal      legal      legal        legal            legal  legal
# 7      ...   legal  not_legal      legal        legal            legal  legal
# ...    ...     ...        ...        ...          ...              ...    ...
# 97263  ...   legal      legal      legal        legal        not_legal  legal
# 97266  ...   legal  not_legal      legal        legal        not_legal  legal
# 97268  ...   legal      legal      legal        legal            legal  legal
# 97269  ...   legal  not_legal      legal        legal        not_legal  legal
# 97270  ...   legal      legal      legal        legal            legal  legal
#
#        oldschool  premodern      predh   tix
# 0      not_legal      legal      legal  0.02
# 1      not_legal  not_legal      legal  0.03
# 2      not_legal  not_legal      legal  0.03
# 4      not_legal  not_legal  not_legal  0.03
# 7      not_legal  not_legal  not_legal  0.03
# ...          ...        ...        ...   ...
# 97263  not_legal  not_legal  not_legal  0.04
# 97266  not_legal  not_legal  not_legal  0.42
# 97268  not_legal      legal      legal  0.03
# 97269  not_legal  not_legal  not_legal  2.22
# 97270  not_legal  not_legal  not_legal  0.03
#
# [46956 rows x 46 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46956 entries, 0 to 97270
# Data columns (total 46 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               46956 non-null  object
#  1   mtgo_id          46956 non-null  float64
#  2   name             46956 non-null  object
#  3   released_at      46956 non-null  object
#  4   layout           46956 non-null  object
#  5   mana_cost        46315 non-null  object
#  6   cmc              46950 non-null  float64
#  7   type_line        46950 non-null  object
#  8   colors           46315 non-null  object
#  9   color_identity   46956 non-null  object
#  10  keywords         46956 non-null  object
#  11  produced_mana    6956 non-null   object
#  12  reserved         46956 non-null  bool
#  13  foil             46956 non-null  bool
#  14  nonfoil          46956 non-null  bool
#  15  promo            46956 non-null  bool
#  16  reprint          46956 non-null  bool
#  17  set_type         46956 non-null  object
#  18  digital          46956 non-null  bool
#  19  rarity           46956 non-null  object
#  20  border_color     46956 non-null  object
#  21  frame            46956 non-null  object
#  22  full_art         46956 non-null  bool
#  23  textless         46956 non-null  bool
#  24  booster          46956 non-null  bool
#  25  story_spotlight  46956 non-null  bool
#  26  power            22595 non-null  object
#  27  toughness        22595 non-null  object
#  28  edhrec_rank      44945 non-null  float64
#  29  penny_rank       29843 non-null  float64
#  30  standard         46956 non-null  object
#  31  future           46956 non-null  object
#  32  pioneer          46956 non-null  object
#  33  modern           46956 non-null  object
#  34  legacy           46956 non-null  object
#  35  pauper           46956 non-null  object
#  36  vintage          46956 non-null  object
#  37  penny            46956 non-null  object
#  38  commander        46956 non-null  object
#  39  oathbreaker      46956 non-null  object
#  40  paupercommander  46956 non-null  object
#  41  duel             46956 non-null  object
#  42  oldschool        46956 non-null  object
#  43  premodern        46956 non-null  object
#  44  predh            46956 non-null  object
#  45  tix              46956 non-null  object
# dtypes: bool(10), float64(4), object(32)
# memory usage: 13.7+ MB

# %%
df4.sample(5)
# Out:
#                                          id    mtgo_id  \
# 31674  5377da39-2152-414f-8b7e-638cb2e127e3 124769.000
# 64166  a8a69f7b-be68-43f7-b1ed-df528bde74e5  23456.000
# 77839  cc9b0c14-c50c-4727-aa2a-3eb25892e8c2  97931.000
# 37801  63325755-47d5-4bb2-a21c-f324c27e1bbd 114327.000
# 84929  df027117-9cb2-428f-b5ab-eb4491493fa3  66199.000
#
#                                   name released_at  layout        mana_cost  \
# 31674                        Big Score  2024-04-19  normal           {3}{R}
# 64166  Sunhome, Fortress of the Legion  2005-10-07  normal
# 77839                 Invoke the Winds  2022-03-15  normal  {1}{U}{U}{U}{U}
# 37801                   Exotic Orchard  2023-08-04  normal
# 84929                  Durkwood Baloth  2017-11-17  normal        {4}{G}{G}
#
#         cmc         type_line colors color_identity  ... vintage      penny  \
# 31674 4.000           Instant    [R]            [R]  ...   legal      legal
# 64166 0.000              Land     []         [R, W]  ...   legal  not_legal
# 77839 5.000           Sorcery    [U]            [U]  ...   legal      legal
# 37801 0.000              Land     []             []  ...   legal      legal
# 84929 6.000  Creature — Beast    [G]            [G]  ...   legal      legal
#
#        commander  oathbreaker  paupercommander   duel  oldschool  premodern  \
# 31674      legal        legal            legal  legal  not_legal  not_legal
# 64166      legal        legal        not_legal  legal  not_legal  not_legal
# 77839      legal        legal        not_legal  legal  not_legal  not_legal
# 37801      legal        legal        not_legal  legal  not_legal  not_legal
# 84929      legal        legal            legal  legal  not_legal  not_legal
#
#            predh   tix
# 31674  not_legal  0.05
# 64166      legal  0.03
# 77839  not_legal  0.13
# 37801      legal  0.02
# 84929      legal  0.06
#
# [5 rows x 46 columns]

# %%
set(df4.set_type)
# Out:
# {'arsenal',
#  'box',
#  'commander',
#  'core',
#  'draft_innovation',
#  'duel_deck',
#  'expansion',
#  'from_the_vault',
#  'funny',
#  'masterpiece',
#  'masters',
#  'planechase',
#  'promo',
#  'starter',
#  'treasure_chest'}

# %%
#housing.sqft_living.hist(bins=100, figsize=(12 ,8))

tix = df4.tix.astype("float64")
tix=tix[tix!=0]
log_tix = np.log10(tix)
tix.describe()
#print(tix)
# Out:
# count   46952.000
# mean        0.414
# std         3.026
# min         0.010
# 25%         0.030
# 50%         0.040
# 75%         0.090
# max       490.660
# Name: tix, dtype: float64

# %%
def convert_variable_to_numbers(data, column_name, data_type):
    engineered_data = data.copy()

    new_column = engineered_data[column_name].astype(data_type)
    engineered_data = engineered_data.drop(columns=column_name).join(new_column)
    return engineered_data

# %%
def convert_all_to_numbers(data = pd.DataFrame) -> pd.DataFrame:
    engineered_data = data.copy()

    engineered_data = convert_variable_to_numbers(engineered_data, "tix", "float64")

    bool_vars = ["reserved","foil","nonfoil","promo","reprint","digital",
                 "story_spotlight","full_art","textless","booster"
                ]
                # "standard","future","pioneer","modern","legacy","pauper","vintage",
                # "penny","commander","oathbreaker","paupercommander","duel",
                # "oldschool","premodern","predh"


    
    for column_name in bool_vars:
        engineered_data = convert_variable_to_numbers(engineered_data, column_name, "int")
        

    


    return engineered_data

# %%
df5 = convert_all_to_numbers(df4)

# %%
def create_log_tix(data = pd.DataFrame) -> pd.DataFrame:
    engineered_data = data.copy()
    tix_values = engineered_data.tix
    log_tix = np.log(np.add(tix_values,0.005)).astype("float64").rename("log_tix")
    print(log_tix)
    engineered_data = engineered_data.join(log_tix)
    return engineered_data

# %%
df6 = create_log_tix(df5)
# Out:
# 0       -3.689
# 1       -3.352
# 2       -3.352
# 4       -3.352
# 7       -3.352
#          ...
# 97263   -3.101
# 97266   -0.856
# 97268   -3.352
# 97269    0.800
# 97270   -3.352
# Name: log_tix, Length: 46956, dtype: float64

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46956 entries, 0 to 97270
# Data columns (total 47 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               46956 non-null  object
#  1   mtgo_id          46956 non-null  float64
#  2   name             46956 non-null  object
#  3   released_at      46956 non-null  object
#  4   layout           46956 non-null  object
#  5   mana_cost        46315 non-null  object
#  6   cmc              46950 non-null  float64
#  7   type_line        46950 non-null  object
#  8   colors           46315 non-null  object
#  9   color_identity   46956 non-null  object
#  10  keywords         46956 non-null  object
#  11  produced_mana    6956 non-null   object
#  12  set_type         46956 non-null  object
#  13  rarity           46956 non-null  object
#  14  border_color     46956 non-null  object
#  15  frame            46956 non-null  object
#  16  power            22595 non-null  object
#  17  toughness        22595 non-null  object
#  18  edhrec_rank      44945 non-null  float64
#  19  penny_rank       29843 non-null  float64
#  20  standard         46956 non-null  object
#  21  future           46956 non-null  object
#  22  pioneer          46956 non-null  object
#  23  modern           46956 non-null  object
#  24  legacy           46956 non-null  object
#  25  pauper           46956 non-null  object
#  26  vintage          46956 non-null  object
#  27  penny            46956 non-null  object
#  28  commander        46956 non-null  object
#  29  oathbreaker      46956 non-null  object
#  30  paupercommander  46956 non-null  object
#  31  duel             46956 non-null  object
#  32  oldschool        46956 non-null  object
#  33  premodern        46956 non-null  object
#  34  predh            46956 non-null  object
#  35  tix              46956 non-null  float64
#  36  reserved         46956 non-null  int64
#  37  foil             46956 non-null  int64
#  38  nonfoil          46956 non-null  int64
#  39  promo            46956 non-null  int64
#  40  reprint          46956 non-null  int64
#  41  digital          46956 non-null  int64
#  42  story_spotlight  46956 non-null  int64
#  43  full_art         46956 non-null  int64
#  44  textless         46956 non-null  int64
#  45  booster          46956 non-null  int64
#  46  log_tix          46956 non-null  float64
# dtypes: float64(6), int64(10), object(31)
# memory usage: 17.2+ MB

# %%
plt.hist(log_tix, bins=60)
plt.show()

# %%
other = df6[df6.rarity=="mythic"]
pd.concat([other, df6[df6.rarity=="special"]])
pd.concat([other, df6[df6.rarity=="bonus"]])

common = df6[df6.rarity=="common"]
uncommon = df6[df6.rarity=="uncommon"]
rare = df6[df6.rarity=="rare"]
mythic = df6[df6.rarity=="mythic"]
bonus = df6[df6.rarity=="bonus"]
special = df6[df6.rarity=="special"]

#other = pd.concat([mythic, bonus, special])

common.info()

plt.plot(np.sort(common.log_tix), color="blue")
plt.plot(np.sort(uncommon.log_tix), color="green")
plt.plot(np.sort(rare.log_tix), color="purple")
plt.plot(np.sort(mythic.log_tix), color="red")
plt.plot(np.sort(special.log_tix), color="orange")
plt.plot(np.sort(bonus.log_tix), color="yellow")

plt.plot(np.sort(other.log_tix), color="black")


plt.legend()
plt.show
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15806 entries, 0 to 97270
# Data columns (total 47 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               15806 non-null  object
#  1   mtgo_id          15806 non-null  float64
#  2   name             15806 non-null  object
#  3   released_at      15806 non-null  object
#  4   layout           15806 non-null  object
#  5   mana_cost        15728 non-null  object
#  6   cmc              15800 non-null  float64
#  7   type_line        15800 non-null  object
#  8   colors           15728 non-null  object
#  9   color_identity   15806 non-null  object
#  10  keywords         15806 non-null  object
#  11  produced_mana    3262 non-null   object
#  12  set_type         15806 non-null  object
#  13  rarity           15806 non-null  object
#  14  border_color     15806 non-null  object
#  15  frame            15806 non-null  object
#  16  power            7234 non-null   object
#  17  toughness        7234 non-null   object
#  18  edhrec_rank      13930 non-null  float64
#  19  penny_rank       9623 non-null   float64
#  20  standard         15806 non-null  object
#  21  future           15806 non-null  object
#  22  pioneer          15806 non-null  object
#  23  modern           15806 non-null  object
#  24  legacy           15806 non-null  object
#  25  pauper           15806 non-null  object
#  26  vintage          15806 non-null  object
#  27  penny            15806 non-null  object
#  28  commander        15806 non-null  object
#  29  oathbreaker      15806 non-null  object
#  30  paupercommander  15806 non-null  object
#  31  duel             15806 non-null  object
#  32  oldschool        15806 non-null  object
#  33  premodern        15806 non-null  object
#  34  predh            15806 non-null  object
#  35  tix              15806 non-null  float64
#  36  reserved         15806 non-null  int64
#  37  foil             15806 non-null  int64
#  38  nonfoil          15806 non-null  int64
#  39  promo            15806 non-null  int64
#  40  reprint          15806 non-null  int64
#  41  digital          15806 non-null  int64
#  42  story_spotlight  15806 non-null  int64
#  43  full_art         15806 non-null  int64
#  44  textless         15806 non-null  int64
#  45  booster          15806 non-null  int64
#  46  log_tix          15806 non-null  float64
# dtypes: float64(6), int64(10), object(31)
# memory usage: 5.8+ MB
# /var/folders/sw/pwx4c2hx5dn8lyy63sj549ch0000gn/T/ipykernel_3666/1903561149.py:26: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df6.columns
# Out:
# Index(['id', 'mtgo_id', 'name', 'released_at', 'layout', 'mana_cost', 'cmc',
#        'type_line', 'colors', 'color_identity', 'keywords', 'produced_mana',
#        'set_type', 'rarity', 'border_color', 'frame', 'power', 'toughness',
#        'edhrec_rank', 'penny_rank', 'standard', 'future', 'pioneer', 'modern',
#        'legacy', 'pauper', 'vintage', 'penny', 'commander', 'oathbreaker',
#        'paupercommander', 'duel', 'oldschool', 'premodern', 'predh', 'tix',
#        'reserved', 'foil', 'nonfoil', 'promo', 'reprint', 'digital',
#        'story_spotlight', 'full_art', 'textless', 'booster', 'log_tix'],
#       dtype='object')

# %%
rarities = [common, uncommon, rare, mythic, special, bonus]

for i in rarities:
    print(np.mean(i.tix))
    print(np.median(i.tix))
    print(len(i))
    print("")
# Out:
# 0.1097051752499051
# 0.04
# 15806
#
# 0.13219146934295126
# 0.04
# 12754
#
# 0.726855169584245
# 0.03
# 14624
#
# 1.4476091415177266
# 0.25
# 3413
#
# 0.9806857142857143
# 0.22
# 350
#
# 10.816666666666665
# 5.47
# 9

# %%
import seaborn as sns

rarities_tix_list = [rarities[i].log_tix for i in range(6)]
rarity_names = ["C","U","R","M","S","B"]

fig, axs = plt.subplots(1,6)

for i in range(6):
    axs[i].boxplot(rarities_tix_list[i])
    axs[i].set_xlabel(rarity_names[i])

# %%
p = df6[
    ["edhrec_rank","penny_rank","cmc","reserved","log_tix"]
].plot.box(subplots=True, layout=(3, 3), figsize=(18,18))

# %%
plt.scatter(df6["edhrec_rank"],df6["log_tix"], alpha=0.05)

# %%
plt.scatter(df6["penny_rank"],df6["log_tix"], alpha=0.1)

# %%
plt.scatter(df6["cmc"],df6["log_tix"], alpha=0.02)

# %%
#plt.scatter(df6["power"],np.log(df6["tix"]), alpha=0.02)

# %%
#plt.scatter(df5["reserved"],np.log(df5["tix"]), alpha=0.005)

# %%
#plt.scatter(df5["foil"],np.log(df5["tix"]), alpha=0.01)

# %%
def ordinate_rarities(data: pd.DataFrame) -> pd.DataFrame:
    ordinate_rarities_dict = {
        "common": 1, 
        "uncommon": 2,
        "rare": 3, 
        "mythic": 4, 
        "special": 5, 
        "bonus": 5, 
    }
    engineered_data = data.copy()
    ordinate_rarity = [ordinate_rarities_dict[x] for x in engineered_data["rarity"]]
    engineered_data.drop(columns="rarity").join(ordinate_rarity)
    return engineered_data
    #ordinate_rarity = ordinate_rarities_dict[tuple(engineered_data["rarity"][:30])[1]]
    #print(ordinate_rarity)

# %%
#df7 = ordinate_rarities(df6)
#df7

# %%
corr_matrix = df6.corr(numeric_only=True)
corr_matrix["log_tix"].sort_values(ascending=False)
# Out:
# log_tix            1.000
# tix                0.397
# mtgo_id            0.234
# promo              0.234
# digital            0.218
# reprint            0.208
# reserved           0.078
# textless           0.034
# full_art           0.027
# cmc               -0.032
# story_spotlight   -0.045
# nonfoil           -0.168
# penny_rank        -0.199
# foil              -0.218
# edhrec_rank       -0.299
# booster           -0.451
# Name: log_tix, dtype: float64

# %%
# Would it be an idea to create a variable of "power / mana value"?

# %%
# BIG PLAN: First, finish data preprocessing (UGHHHHHH)
# Then create a baseline model (it'll suck - dataset is highly biased)
# Then downweight low prices (exclude a subset of cards with 0.01 or 0.02 tix from the dataset)
