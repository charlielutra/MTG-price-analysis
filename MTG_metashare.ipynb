# %% [markdown]
# DESCRIPTION
#
# Start with just standard. Smallest number of legal cards, so should be easier.
#
# So: Take the scryfall database and keep only the STANDARD-LEGAL cards.
# Use the version that only has 1 entry per cardname.
#
#
#
# Use the database here: https://github.com/fbettega/MTG_decklistcache
# ... to find decklists entered into recent tournaments.

# %%
# Setup - copy-pasted from 2A

# Python ≥3.9 is required
import sys
assert sys.version_info >= (3, 9)

# Scikit-Learn ≥1.0 is required
import sklearn
assert sklearn.__version__ >= "1.0"

# Common imports
import numpy as np
import pandas as pd

# To plot pretty figures
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Precision options
np.set_printoptions(precision=2)
pd.options.display.float_format = '{:.3f}'.format

# Statistical analysis and testing
from statsmodels.formula.api import ols
import statsmodels.api as sm

# Ignore useless warnings (see SciPy issue #5998 and seaborn/matplotlib bug)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")
warnings.filterwarnings(action="ignore", message="The figure layout has changed to tight")

import json
import datetime

import requests

# %%
import scryfall_preprocessing as sf

# %%
#from importlib import reload
#reload(sf)
# Out:
# <module 'scryfall_preprocessing' from '/Users/charlie/DataScience/mtg_price_analysis/scryfall_preprocessing.py'>

# %%
my_cards = sf.get_cards()

# %%
my_cards
# Out:
#       object                                    id  \
# 0       card  a471b306-4941-4e46-a0cb-d92895c16f8a
# 1       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 2       card  7050735c-b232-47a6-a342-01795bfd0d46
# 3       card  e718b21b-46d1-4844-985c-52745657b1ac
# 4       card  036ef8c9-72ac-46ce-af07-83b79d736538
# ...      ...                                   ...
# 35267   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 35268   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 35269   card  22a6a5f1-1405-4efb-af3e-e1f58d664e99
# 35270   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 35271   card  1ecc983e-bbe3-4bc1-97e9-e40ead987ef0
#
#                                   oracle_id    multiverse_ids    mtgo_id  \
# 0      00037840-6089-42ec-8c5c-281f9f474504          [692174] 137223.000
# 1      0004ebd0-dfd6-4276-b4a6-de0003e94237           [15862]  15870.000
# 2      0006faf6-7a61-426c-9034-579f2cfcfa83          [370780]  49283.000
# 3      0007c283-5b7a-4c00-9ca1-b455c8dff8c3          [470580]  77122.000
# 4      000d5588-5a4c-434e-988d-396632ade42c           [83282]  22609.000
# ...                                     ...               ...        ...
# 35267  fffa9334-3576-4f70-9605-2ad062cdbc69          [430770]  64646.000
# 35268  fffaa634-42a0-4038-b027-24f28754fec7          [571548] 101914.000
# 35269  fffcb71f-e802-436e-917d-eaa6607ab74f  [503766, 503767]  87643.000
# 35270  fffdc2ac-bde4-4e4c-a5bd-0e6c6e49ad91          [430833]  64772.000
# 35271  ffff90c3-63c4-4dee-a21d-6b2b113f4f80          [625242] 114015.000
#
#        tcgplayer_id  cardmarket_id                                    name  \
# 0        615195.000     807933.000                Nissa, Worldsoul Speaker
# 1          3094.000       3081.000                              Static Orb
# 2         69965.000     262945.000                     Sensory Deprivation
# 3        196536.000     391692.000                          Road of Return
# 4         12835.000      12551.000                              Storm Crow
# ...             ...            ...                                     ...
# 35267    136683.000     298834.000                        Without Weakness
# 35268    276869.000     665173.000                 Firesong and Sunspeaker
# 35269    230214.000     530502.000  Toralf, God of Fury // Toralf's Hammer
# 35270    132234.000     298282.000                       Samut, the Tested
# 35271    505126.000     722911.000                            Sinew Sliver
#
#       lang released_at  ... produced_mana tcgplayer_etched_id loyalty  \
# 0       en  2025-02-14  ...           NaN                 NaN     NaN
# 1       en  2001-04-11  ...           NaN                 NaN     NaN
# 2       en  2013-07-19  ...           NaN                 NaN     NaN
# 3       en  2019-08-23  ...           NaN                 NaN     NaN
# 4       en  2005-07-29  ...           NaN                 NaN     NaN
# ...    ...         ...  ...           ...                 ...     ...
# 35267   en  2017-07-14  ...           NaN                 NaN     NaN
# 35268   en  2022-07-08  ...           NaN                 NaN     NaN
# 35269   en  2021-02-05  ...           NaN                 NaN     NaN
# 35270   en  2017-07-14  ...           NaN                 NaN       4
# 35271   en  2023-08-04  ...           NaN                 NaN     NaN
#
#        life_modifier hand_modifier attraction_lights color_indicator  \
# 0                NaN           NaN               NaN             NaN
# 1                NaN           NaN               NaN             NaN
# 2                NaN           NaN               NaN             NaN
# 3                NaN           NaN               NaN             NaN
# 4                NaN           NaN               NaN             NaN
# ...              ...           ...               ...             ...
# 35267            NaN           NaN               NaN             NaN
# 35268            NaN           NaN               NaN             NaN
# 35269            NaN           NaN               NaN             NaN
# 35270            NaN           NaN               NaN             NaN
# 35271            NaN           NaN               NaN             NaN
#
#        flavor_name content_warning defense
# 0              NaN             NaN     NaN
# 1              NaN             NaN     NaN
# 2              NaN             NaN     NaN
# 3              NaN             NaN     NaN
# 4              NaN             NaN     NaN
# ...            ...             ...     ...
# 35267          NaN             NaN     NaN
# 35268          NaN             NaN     NaN
# 35269          NaN             NaN     NaN
# 35270          NaN             NaN     NaN
# 35271          NaN             NaN     NaN
#
# [35272 rows x 83 columns]

# %%
standard_cards = sf.standard_only(my_cards)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sw/pwx4c2hx5dn8lyy63sj549ch0000gn/T/ipykernel_12657/713157358.py in ?()
# ----> 1 standard_cards = sf.standard_only(my_cards)
#
# ~/DataScience/mtg_price_analysis/scryfall_preprocessing.py in ?(data)
#     173     """
#     174     Returns a DataFrame containing only cards that are legal in Standard.
#     175     """
#     176     engineered_data = data.copy()
# --> 177     return engineered_data[engineered_data.standard == "legal"]
#
# ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'standard'
